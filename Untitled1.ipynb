# %%
import argparse
import time
import schedule
import dns
import csv
import argparse
import subprocess
import re
import json

def query(domainlist, storage_format, savefile):
    with open(domainlist, 'r+') as fr:
        entriesTitle = ['Domain Name Returned', 'TTL', 'Unknown', 'Query Type', 'IP address']
        output_file = savefile + storage_format
        with open(output_file, 'w+') as fw:
            if (storage_format == 'csv'):
                writer = csv.writer(fw, quotechar='|', quoting=csv.QUOTE_MINIMAL)

                writer.writerow(['Domain Queried', 'Answer Type'] + entriesTitle)
            domain = fr.readline()
            j = 1
            query_list = {}
            while (domain):
                temp = re.findall(r',([\w\.]+)', domain)
                print(temp)
                domain = temp[0]
                result = subprocess.run(['dig', '+nocmd', '+noquestion', 'ANY', domain], stdout = subprocess.PIPE)
                str = result.stdout.decode("UTF-8")
                length = len(match)
                i = 0
                if (storage_format == 'csv'):
                    while (i < length):
                        if (re.search(r':$', match[i])):
                            temp = re.search(r'(\w+):$', match[i])
                            if (temp.groups(1) == 'answer'):
                                break
                            element = re.findall(r'([\w\s]*):', match[i])
                            answer_type = element[0]
                            i += 1
                            while(re.search(r'^[^;]', match[i]) != None):
                                element = re.findall(r'([\w+\.:]+)\.?\t?', match[i])

                                element = [j] + [domain] + [answer_type] + element
                                writer.writerow(element)
    #                             json.dump(element, fw)
                                i += 1
                                if (i == length):
                                    break
                            i -= 1

                        i += 1
                if (storage_format == 'json'):

                    while (i < length):
                        section_dict = {} 
                        if (re.search(r':$', match[i])):
                            temp = re.search(r'(\w+):$', match[i])
                            if (temp.groups(1) == 'answer'):
                                break
                            element = re.findall(r'([\w\s]*):', match[i])
                            answer_type = element[0]
                            i += 1
                            element_list = []
                            while(re.search(r'^[^;]', match[i]) != None):
                                element = re.findall(r'([\w+\.:]+)\.?\t?', match[i])
        #                         writer.writerow(element)
    #                             json.dump(element, fw)
                                element = dict(zip(entriesTitle, element))
                                element_list.append(element)
                                i += 1
    #                             if (i == length):
    #                                 break
    #                             section_list.a
                            i -= 1
                        section_dict[answer_type] = element_list
                        query_list[domain] = section_dict
                        i += 1

                j += 1
    #             json.dump({domain: section_dict}, fw)

                domain = fr.readline()
            if (storage_format == 'json'):
                json.dump(query_list, fw)


if __name__ == "__main__":
    parser = argparse.ArgumentParser();
    parser.add_argument("mode", help = "file which contains the list of domains to query, 1 on each line", default = "top-1m.csv")
    parser.add_argument("writeFile", help = "name of the file in which databsae is to be created", default = "DNS Data.txt")
    parser.add_argument("logFile", help = "log file")
    args = parser.parse_args()
    query(args.domainList, args.writeFile, args.logFile)
# Out:
# usage: ipykernel_launcher.py [-h] mode writeFile logFile
# ipykernel_launcher.py: error: the following arguments are required: writeFile, logFile
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import subprocess
result = subprocess.run(['dig', '+nocmd', '+noquestion', 'ANY', domain], stdout = subprocess.PIPE)
print(result.stdout.decode('UTF-8'))

# %%
import argparse
import time
import schedule
import dns
import csv
import argparse
import subprocess
import re
import json
with open("top-1mshort.csv", 'r+') as fr:
        entriesTitle = ['Domain Name Returned', 'TTL', 'Unknown', 'Query Type', 'IP address']
        with open("DNS Data.txt", 'w+') as fw:
            writer = csv.writer(fw)
            writer.writerow(['Domain Queried', 'Answer Type'] + entriesTitle)
            domain = fr.readline()
            j = 1
            query_list = {}
            while (domain):
                temp = re.findall(r',([\w\.]+)', domain)
                print(temp)
                domain = temp[0]
                result = subprocess.run(['dig', '+nocmd', '+noquestion', 'ANY', domain], stdout = subprocess.PIPE)
                match = result.stdout.decode("UTF-8")
                length = len(match)
                i = 0
                while (i < length):
                    temp = re.search(r'(\w+):$', match[i])
                    if (temp.groups(1) == 'answer'):
                        break
                    element = re.findall(r'([\w\s]*):', match[i])
                    answer_type = element[0]
                    i += 1
                    while(re.search(r'^[^;]', match[i]) != None):
                        element = re.findall(r'([\w+\.:]+)\.?\t?', match[i])

                        element = [j] + [domain] + [answer_type] + element
                        writer.writerow(element)
#                             json.dump(element, fw)
                        i += 1
                        if (i == length):
                            break
                    i -= 1

                    i += 1
                j += 1
                domain = fr.readline()
# Out:
# ['google.com']
# ['youtube.com']
# ['facebook.com']
# ['baidu.com']
# ['wikipedia.org']
# ['reddit.com']
# ['yahoo.com']
# ['google.co.in']
# ['qq.com']
# ['amazon.com']
# ['taobao.com']
# ['twitter.com']
# ['tmall.com']
# ['vk.com']
# ['instagram.com']
# ['live.com']
# ['google.co.jp']
# ['sohu.com']
# ['sina.com.cn']
# ['jd.com']
# ['weibo.com']
# ['360.cn']
# ['google.de']
# ['google.co.uk']
# ['google.com.br']
# ['google.fr']
# ['list.tmall.com']
# ['google.ru']
# ['netflix.com']
# ['yandex.ru']
# ['google.it']
# ['google.com.hk']
# ['linkedin.com']
# ['t.co']
# ['twitch.tv']
# ['pornhub.com']
# ['google.es']
# ['xvideos.com']
# ['alipay.com']
# ['ebay.com']
# ['yahoo.co.jp']
# ['google.ca']
# ['google.com.mx']
# ['bing.com']
# ['imgur.com']
# ['ok.ru']
# ['microsoft.com']
# ['imdb.com']
# ['wikia.com']
# ['bongacams.com']

# %%
import subprocess
result = subprocess.run(['dig', '+nocmd', '+noquestion', 'ANY', "google.com"], stdout = subprocess.PIPE)
print(result.stdout.decode('UTF-8'))
print("end")
# Out:
# ;; Got answer:
# ;; ->>HEADER<<- opcode: QUERY, status: NOERROR, id: 37876
# ;; flags: qr rd ra; QUERY: 1, ANSWER: 10, AUTHORITY: 4, ADDITIONAL: 9
#
# ;; ANSWER SECTION:
# google.com.		578	IN	MX	10 aspmx.l.google.com.
# google.com.		578	IN	MX	30 alt2.aspmx.l.google.com.
# google.com.		578	IN	MX	50 alt4.aspmx.l.google.com.
# google.com.		578	IN	MX	40 alt3.aspmx.l.google.com.
# google.com.		578	IN	MX	20 alt1.aspmx.l.google.com.
# google.com.		73293	IN	NS	ns3.google.com.
# google.com.		73293	IN	NS	ns4.google.com.
# google.com.		73293	IN	NS	ns2.google.com.
# google.com.		73293	IN	NS	ns1.google.com.
# google.com.		274	IN	A	216.58.221.46
#
# ;; AUTHORITY SECTION:
# google.com.		73293	IN	NS	ns3.google.com.
# google.com.		73293	IN	NS	ns4.google.com.
# google.com.		73293	IN	NS	ns2.google.com.
# google.com.		73293	IN	NS	ns1.google.com.
#
# ;; ADDITIONAL SECTION:
# alt4.aspmx.l.google.com. 272	IN	A	64.233.176.26
# ns1.google.com.		225981	IN	A	216.239.32.10
# ns1.google.com.		213469	IN	AAAA	2001:4860:4802:32::a
# ns2.google.com.		226020	IN	A	216.239.34.10
# ns2.google.com.		213469	IN	AAAA	2001:4860:4802:34::a
# ns3.google.com.		226203	IN	A	216.239.36.10
# ns3.google.com.		213469	IN	AAAA	2001:4860:4802:36::a
# ns4.google.com.		226203	IN	A	216.239.38.10
# ns4.google.com.		213469	IN	AAAA	2001:4860:4802:38::a
#
# ;; Query time: 2 msec
# ;; SERVER: 10.10.2.2#53(10.10.2.2)
# ;; WHEN: Sun May 20 01:32:35 2018
# ;; MSG SIZE  rcvd: 472
#
#
# end

# %%
import csv
import subprocess
import re

with open('top-1m.csv', 'r+') as fr:
    with open('DNS Data.csv', 'w+') as fw:
        domain = fr.readline()
        writer = csv.writer(fw, quotechar='|', quoting=csv.QUOTE_MINIMAL)
        writer.writerow(['Domain Queried', 'Answer Type', 'Domain Name Returned', 'TTL', 'Unknown', 'Query Type', 'IP address'])
        j = 1
        while (domain):
            temp = re.findall(r',([\w\.]+)', domain)
            domain = temp[0]
            result = subprocess.run(['dig', '+nocmd', '+noquestion', 'ANY', domain], stdout = subprocess.PIPE)
            str = result.stdout.decode("UTF-8")
            # pos_answer = findnth(str,"ANSWER", 1)
            # # print(pos_answer)
            # str_temp = str
            # pos_authority = findnth(str, "AUTHORITY", 1, offset = 103)
            # # print(pos_authority)
            # pos_additional = findnth(str, "ADDITIONAL", 1, offset = pos_authority)
            # # regex = re.compile(r'SECTION:\s+()')
            match = re.findall(r'.+(?!SECTION)', str)
            length = len(match)
            i = 0
            while (i < length):
                if (re.search(r':$', match[i])):
                    temp = re.search(r'(\w+):$', match[i])
                    if (temp.groups(1) == 'answer'):
                        break
                    
                    
                    element = re.findall(r'([\w\s]*):', match[i])
                    answer_type = element[0]
                    i += 1
                    while(re.search(r'^[^;]', match[i]) != None):
                        element = re.findall(r'([\w+\.:]+)\.?\t?', match[i])

                        element = [j] + [domain] + [answer_type] + element
                        writer.writerow(element)
                        i += 1
                        if (i == length):
                            break
                    i -= 1

                i += 1
            j += 1
            domain = fr.readline()
